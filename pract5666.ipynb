# %%
import pandas as pn 
skyrim = pn.read_csv('Skyrim_Weapons.csv')

skyrim
# Out:
#                                 Name  Damage  Weight  Gold  \
# 0            Ancient Nord Battle Axe      18    22.0    28
# 1                  Daedric Battleaxe      25    27.0  2750
# 2              Dragonbone Battleaxe       26    30.0  3000
# 3               Drainblood Battleaxe      21     5.0   266
# 4                  Dwarven Battleaxe      20    23.0   300
# ..                               ...     ...     ...   ...
# 288      Exploding Steel Bolt of Ice      10     0.0     5
# 289    Exploding Steel Bolt of Shock      10     0.0     5
# 290   Exploding Dwarven Bolt of Fire      14     0.0    15
# 291    Exploding Dwarven Bolt of Ice      14     0.0    15
# 292  Exploding Dwarven Bolt of Shock      14     0.0    15
#
#                  Upgrade     Perk       Type    Category  Speed
# 0            Steel Ingot    Steel  Battleaxe  Two-Handed    NaN
# 1            Ebony Ingot  Daedric  Battleaxe  Two-Handed    NaN
# ...

# %% [markdown]
# Цель работы: проанализировать свой скачанный датасет, а именно: вывести весь датасет и описать его, вывести размерноть массива, вывести наименование всех колонок, написать что они означают в датасете, вывести все уникальные значения, отсортировать по определенным параметрам, удалить ненужные столбцы или строчки, заменить определенные значения в датасете (например, пустые), удалить дубликаты, провести анализ с помощью функций info, провести анализ с помощью функций describe, провести выборку данных по строкам и столбцам с помощью loc, сохранить новый датасет, сделать вывод по каждому пункту и описать все.
#
# Это датасет, содержащий информацию по оружиям из скайрима. Есть столбец с именем оружия, его уроном, весом, стоимостью, возможностью прокачки, видом, типом, категорией и скоростью удара.

# %%
skyrim.head(20)
# Out:
#                               Name  Damage  Weight  Gold              Upgrade  \
# 0          Ancient Nord Battle Axe      18    22.0    28          Steel Ingot
# 1                Daedric Battleaxe      25    27.0  2750          Ebony Ingot
# 2            Dragonbone Battleaxe       26    30.0  3000          Dragon Bone
# 3             Drainblood Battleaxe      21     5.0   266                  NaN
# 4                Dwarven Battleaxe      20    23.0   300  Dwarven Metal Ingot
# 5                  Ebony Battleaxe      23    26.0  1585          Ebony Ingot
# 6                  Elven Battleaxe      21    24.0   520    Refined Moonstone
# 7                  Glass Battleaxe      22    25.0   900    Refined Malachite
# 8                   Headsman's Axe      17    11.0    15                  NaN
# 9    Honed Ancient Nord Battle Axe      21    25.0    50          Steel Ingot
# 10                  Iron Battleaxe      16    20.0    55           Iron Ingot
# ...

# %% [markdown]
# Вывод первых 20 значений(отсчет идет с нуля, поэтому выводятся до 19)

# %%
skyrim.tail(20)
# Out:
#                                 Name  Damage  Weight  Gold  \
# 273                  Nordic Arrow DR      14     0.0     4
# 274                     Orcish Arrow      12     0.0     3
# 275                   Practice Arrow       0     0.0     0
# 276                Riekling Spear DR      10     0.0     2
# 277                      Rusty Arrow       4     0.0     0
# 278                Stalhrim Arrow DR      20     0.0     7
# 279                      Steel Arrow      10     0.0     2
# 280       Sunhallowed Elven Arrow DG      16     0.0    16
# 281                         Crossbow      19    14.0   120
# 282                 Dwarven Crossbow      22    20.0   350
# 283                Enhanced Crossbow      19    15.0   200
# 284        Enhanced Dwarven Crossbow      22    21.0   550
# 285                       Steel Bolt      10     0.0     1
# 286                     Dwarven Bolt      14     0.0     3
# 287     Exploding Steel Bolt of Fire      10     0.0     5
# ...

# %% [markdown]
# Вывод последних 20 значений

# %%
skyrim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293 entries, 0 to 292
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      293 non-null    object
#  1   Damage    293 non-null    int64
#  2   Weight    293 non-null    float64
#  3   Gold      293 non-null    int64
#  4   Upgrade   232 non-null    object
#  5   Perk      210 non-null    object
#  6   Type      293 non-null    object
#  7   Category  293 non-null    object
#  8   Speed     39 non-null     float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 20.7+ KB

# %% [markdown]
# Анализ данных с помощью команды info(выводит количество столбцов, значения non-null, типы данных, использование памяти)

# %%
skyrim.nunique()
# Out:
# Name        285
# Damage       28
# Weight       39
# Gold        185
# Upgrade      18
# Perk         11
# Type         12
# Category      3
# Speed        11
# dtype: int64

# %% [markdown]
# Выводит количество уникальных значений в каждом столбце

# %%
skyrim["Name"].nunique()
# Out:
# 285

# %% [markdown]
# Вывод уникальных значений в столбце с названием оружия

# %%
skyrim["Damage"].nunique()
# Out:
# 28

# %% [markdown]
# Вывод уникальных значений в столбце урона

# %%
skyrim["Weight"].nunique()
# Out:
# 39

# %% [markdown]
# Вывод уникальных значений в столбце веса

# %%
skyrim["Gold"].nunique()
# Out:
# 185

# %% [markdown]
# Вывод уникальных значений в столбце стоимости

# %%
skyrim["Upgrade"].nunique()
# Out:
# 18

# %% [markdown]
# Вывод уникальных значений в столбце возможности улучшения

# %%
skyrim["Perk"].nunique()
# Out:
# 11

# %% [markdown]
# Вывод уникальных значений в столбце вида

# %%
skyrim["Type"].nunique()
# Out:
# 12

# %% [markdown]
# Вывод уникальных значений в столбце типа

# %%
skyrim["Category"].nunique()
# Out:
# 3

# %% [markdown]
# Вывод уникальных значений в столбце категории

# %%
skyrim["Speed"].nunique()
# Out:
# 11

# %% [markdown]
# Вывод уникальных значений в столбце скорости

# %%
skyrim.sort_values(by='Name')
# Out:
#                      Name  Damage  Weight  Gold              Upgrade     Perk  \
# 203             Aegisbane      18    24.0   180           Iron Ingot      NaN
# 68         Akaviri Sword       11    10.0   300                  NaN        -
# 22    Alessandra's Dagger       5     1.0    10                  NaN        -
# 69   Amren's Family Sword       7     9.0    25           Iron Ingot      NaN
# 261    Ancient Nord Arrow      10     0.0     1                  NaN      NaN
# ..                    ...     ...     ...   ...                  ...      ...
# 142             Windshear      11    10.0    40          Steel Ingot    Steel
# 180      Woodcutter's Axe       5    10.0     5                  NaN        –
# 143         Wooden Sword        2     3.0    25             Firewood      NaN
# 21               Wuuthrad      25    25.0  2000                  NaN        -
# 260             Zephyr DG      12    10.0   670  Dwarven Metal Ingot  Dwarven
#
# ...

# %% [markdown]
# Фильтрация данных по столбцу названия оружия(по алфавиту)

# %%
skyrim[skyrim['Damage'] == 18]
# Out:
#                                Name  Damage  Weight  Gold           Upgrade  \
# 0           Ancient Nord Battle Axe      18    22.0    28       Steel Ingot
# 16   Steel Battleaxe of Fiery Souls      18    21.0   320       Steel Ingot
# 17                  Steel Battleaxe      18    21.0   100       Steel Ingot
# 197               Orcish Greatsword      18    18.0    75  Orichalcum Ingot
# 203                       Aegisbane      18    24.0   180        Iron Ingot
# 213                  Iron Warhammer      18    24.0    60        Iron Ingot
# 271                     Glass Arrow      18     0.0     6               NaN
#
#        Perk        Type    Category  Speed
# 0     Steel   Battleaxe  Two-Handed    NaN
# 16    Steel   Battleaxe  Two-Handed    NaN
# 17    Steel   Battleaxe  Two-Handed    NaN
# 197  Orcish  Greatsword  Two-Handed    NaN
# 203     NaN   Warhammer  Two-Handed    NaN
# 213     NaN   Warhammer  Two-Handed    NaN
# 271     NaN       Arrow     Archery    NaN

# %% [markdown]
# Фильтрация данных по столбцу урона с условием, что он должен равняться 18

# %%
skyrim[skyrim['Type'] == 'Battleaxe']
# Out:
#                               Name  Damage  Weight  Gold              Upgrade  \
# 0          Ancient Nord Battle Axe      18    22.0    28          Steel Ingot
# 1                Daedric Battleaxe      25    27.0  2750          Ebony Ingot
# 2            Dragonbone Battleaxe       26    30.0  3000          Dragon Bone
# 3             Drainblood Battleaxe      21     5.0   266                  NaN
# 4                Dwarven Battleaxe      20    23.0   300  Dwarven Metal Ingot
# 5                  Ebony Battleaxe      23    26.0  1585          Ebony Ingot
# 6                  Elven Battleaxe      21    24.0   520    Refined Moonstone
# 7                  Glass Battleaxe      22    25.0   900    Refined Malachite
# 8                   Headsman's Axe      17    11.0    15                  NaN
# 9    Honed Ancient Nord Battle Axe      21    25.0    50          Steel Ingot
# 10                  Iron Battleaxe      16    20.0    55           Iron Ingot
# ...

# %% [markdown]
# Фильтрация данных по столбцу типа с условием, что он должен быть боевым топором

# %%
deletedata = skyrim.drop_duplicates()

# %% [markdown]
# Удаление дубликатов

# %%
skyrim['Damage'].unique()
# Out:
# array([18, 25, 26, 21, 20, 23, 22, 17, 16, 19, 24, 27,  5, 12, 10,  8, 11,
#         6,  7,  9,  4, 13, 14, 15,  1,  2, 28,  0], dtype=int64)

# %% [markdown]
# Вывод уникальных значений столбца урона

# %%
skyrim['Upgrade'].unique()
# Out:
# array(['Steel Ingot', 'Ebony Ingot', 'Dragon Bone', nan,
#        'Dwarven Metal Ingot', 'Refined Moonstone', 'Refined Malachite',
#        'Iron Ingot', 'Quicksilver Ingot', 'Orichalcum Ingot', 'Stalhrim',
#        'None required', 'Chaurus Chitin', '3 Ectoplasm',
#        'Daedra HeartEbony Ingot', 'Firewood', 'Silver Ingot',
#        'Leather Strips', 'Dwarven metal ingot'], dtype=object)

# %% [markdown]
# Вывод уникальных значений столбца возможности улучшения

# %%
skyrim.shape
# Out:
# (293, 9)

# %% [markdown]
# Вывод размерности массива

# %%
skyrim.describe()
# Out:
#            Damage      Weight         Gold      Speed
# count  293.000000  293.000000   293.000000  39.000000
# mean    13.017065   12.590444   521.300341   0.765923
# std      5.692736    7.649840   732.009566   0.165776
# min      0.000000    0.000000     0.000000   0.500000
# 25%      9.000000    9.000000    45.000000   0.625000
# 50%     12.000000   12.000000   188.000000   0.750000
# 75%     17.000000   17.000000   727.000000   0.875000
# max     28.000000   36.000000  4275.000000   1.000000

# %% [markdown]
# Анализ с помощью describe(описание)

# %%
skyrim.describe().count()
# Out:
# Damage    8
# Weight    8
# Gold      8
# Speed     8
# dtype: int64

# %% [markdown]
# Вывод количества записей, которые участвуют в подсчете остальных статистических показателей.

# %%
locdata = skyrim.loc[0]
locdata
# Out:
# Name        Ancient Nord Battle Axe
# Damage                           18
# Weight                         22.0
# Gold                             28
# Upgrade                 Steel Ingot
# Perk                          Steel
# Type                      Battleaxe
# Category                 Two-Handed
# Speed                           NaN
# Name: 0, dtype: object

# %% [markdown]
# Фильтрация датасета с помощью loc

# %%
rowdata = skyrim.loc[[0, 1, 2, 3], ['Damage', 'Weight']]
rowdata
# Out:
#    Damage  Weight
# 0      18    22.0
# 1      25    27.0
# 2      26    30.0
# 3      21     5.0

# %% [markdown]
# Вывод двух столбцов и 4 строк(0, 1, 2, 3)

# %%
rediska = skyrim.loc[skyrim['Type'] == 'Battleaxe']
rediska
# Out:
#                               Name  Damage  Weight  Gold              Upgrade  \
# 0          Ancient Nord Battle Axe      18    22.0    28          Steel Ingot
# 1                Daedric Battleaxe      25    27.0  2750          Ebony Ingot
# 2            Dragonbone Battleaxe       26    30.0  3000          Dragon Bone
# 3             Drainblood Battleaxe      21     5.0   266                  NaN
# 4                Dwarven Battleaxe      20    23.0   300  Dwarven Metal Ingot
# 5                  Ebony Battleaxe      23    26.0  1585          Ebony Ingot
# 6                  Elven Battleaxe      21    24.0   520    Refined Moonstone
# 7                  Glass Battleaxe      22    25.0   900    Refined Malachite
# 8                   Headsman's Axe      17    11.0    15                  NaN
# 9    Honed Ancient Nord Battle Axe      21    25.0    50          Steel Ingot
# 10                  Iron Battleaxe      16    20.0    55           Iron Ingot
# ...

# %% [markdown]
# Сортировка с помощью loc. Выводятся значения где тип - боевой топор

# %%
deldata = deletedata.drop(columns=['Gold'])

# %% [markdown]
# Удаление столбца с ценой

# %%
rep = deldata.replace({'Upgrade' : 'NaN'}, 'NyYaXz')

# %% [markdown]
# Замена значений в определенном столбце

# %%
rep.to_csv('newfile_skyrim.csv', index=False)
